# %% [markdown]
# ## Import Data

# %%
# !pip install pandas

# %%
current_dir = os.getcwd()
print(f" current dir {current_dir}")
# Out:
#  current dir /content

# %%
import pandas as pd

# 1. Define the file names and the correct delimiter
input_file = 'data/MachineLearningRating_v3.txt'
output_file = 'data/MachineLearningRating_v3.csv'

# **Crucial: Replace '\t' with the actual delimiter (e.g., ',', ';', or ' ')**
delimiter_type = '\t'

# 2. Read the text file into a DataFrame
# Pandas' read_csv can handle most delimited text files, not just commas.
df = pd.read_csv(input_file, sep=delimiter_type)

# 3. Write the DataFrame to a new CSV file
# index=False prevents writing the DataFrame's row numbers as a column
df.to_csv(output_file, index=False)

print(f"Successfully converted {input_file} to {output_file}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3904614961.py in <cell line: 0>()
#      10 # 2. Read the text file into a DataFrame
#      11 # Pandas' read_csv can handle most delimited text files, not just commas.
# ---> 12 df = pd.read_csv(input_file, sep=delimiter_type)
#      13
#      14 # 3. Write the DataFrame to a new CSV file
#
# ...

# %% [markdown]
# ## Import Libraries

# %%
import sys
import os
import pandas as pd

# %% [markdown]
# ## Data Summarization

# %% [markdown]
# ## Data Quality Assesment

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ## Data Comparison

# %% [markdown]
# ## Outlier Detection

# %% [markdown]
# ## EDA Visualization
